# %% [markdown]
# <a href="https://colab.research.google.com/github/jellis451-code/CSC121-Spring2026-AssignmentsWeek-7/blob/main/Welcome_To_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# IMPORT STATEMENTS
# (None)

# FUNCTION DEFINITIONS
# 1. Define verify_pin():
#    - Use a while loop to ask for a PIN
#    - Loop until the PIN equals "1234"
#    - Return True when correct

# 2. Define withdraw(balance, amount):
#    - Check if amount <= balance
#    - Return updated balance or original balance

# PROGRAM LOGIC
# 1. Set current_balance to 500
# 2. Call verify_pin()
# 3. Ask user for withdrawal amount
# 4. Call withdraw() and update balance
# 5. Print final balance
